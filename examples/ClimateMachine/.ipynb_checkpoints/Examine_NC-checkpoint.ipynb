# %%
import xarray as xr

# %%
Ds = xr.open_dataset('./clima_parameters_008.nc')
Ds

# %%
Ds['alpha'].plot()

# %%
pwd
# Out:
# '/glade/work/wchapman/MovingMountains_Calibrate/examples/ClimateMachine'
