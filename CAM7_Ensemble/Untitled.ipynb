# %%
import xarray as xr

# %%
DS = xr.open_dataset('./CESM_parameter_229_231.nc')
DS['Sample_nmb'].values
# Out:
# array(['229', '230', '231'], dtype='<U3')

# %%
DS
# Out:
# <xarray.Dataset>
# Dimensions:                    (nmb_sim: 3)
# Dimensions without coordinates: nmb_sim
# Data variables: (12/46)
#     Sample_nmb                 (nmb_sim) <U3 '229' '230' '231'
#     cldfrc_dp1                 (nmb_sim) float64 ...
#     cldfrc_dp2                 (nmb_sim) float64 ...
#     clubb_C2rt                 (nmb_sim) float64 ...
#     clubb_C6rt                 (nmb_sim) float64 ...
#     clubb_C6rtb                (nmb_sim) float64 ...
#     ...                         ...
#     zmconv_ke                  (nmb_sim) float64 ...
#     zmconv_ke_lnd              (nmb_sim) float64 ...
#     zmconv_momcd               (nmb_sim) float64 ...
#     zmconv_momcu               (nmb_sim) float64 ...
#     zmconv_num_cin             (nmb_sim) int64 ...
#     zmconv_tiedke_add          (nmb_sim) float64 ...
# Attributes:
#     history:  Mon Nov 15 14:44:21 2021: ncks -d nmb_sim,228,230 parameter_250...
# ...
